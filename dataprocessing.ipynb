# %% [markdown]
# ##### Data Cleaning of Heroes Information!

# %% [markdown]
# ##### Now import Pandas

# %%
import pandas as pd

# %% [markdown]
# ##### df as (Variable) is Equal to our file (Value)

# %%
df = pd.read_csv("heroes_information.csv")

# %% [markdown]
# ##### For Data Names :

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'Gender', 'Eye color', 'Race', 'Hair color',
#        'Height', 'Publisher', 'Skin color', 'Alignment', 'Weight'],
#       dtype='object')

# %% [markdown]
# ##### Top Data Names

# %%
df.head(3)
# Out:
#    Unnamed: 0        name Gender Eye color           Race Hair color  Height  \
# 0           0      A-Bomb   Male    yellow          Human    No Hair   203.0
# 1           1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
# 2           2    Abin Sur   Male      blue        Ungaran    No Hair   185.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0

# %% [markdown]
# ##### Columns and Rows :

# %%
df.tail(3)
# Out:
#      Unnamed: 0     name  Gender Eye color            Race Hair color  Height  \
# 731         731     Yoda    Male     brown  Yoda's species      White    66.0
# 732         732  Zatanna  Female      blue           Human      Black   170.0
# 733         733     Zoom    Male       red               -      Brown   185.0
#
#         Publisher Skin color Alignment  Weight
# 731  George Lucas      green      good    17.0
# 732     DC Comics          -      good    57.0
# 733     DC Comics          -       bad    81.0

# %% [markdown]
# ##### Total Rows and columns

# %%
df.shape
# Out:
# (734, 11)

# %% [markdown]
# #### Random Data pick

# %%
df.sample(3)
# Out:
#      Unnamed: 0         name Gender Eye color    Race Hair color  Height  \
# 613         613  Space Ghost   Male         -   Human          -   188.0
# 47           47        Atlas   Male     brown  Mutant        Red   183.0
# 112         112  Blaquesmith      -     black       -    No Hair   -99.0
#
#          Publisher Skin color Alignment  Weight
# 613      DC Comics          -      good   113.0
# 47   Marvel Comics          -      good   101.0
# 112  Marvel Comics          -      good   -99.0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'Gender', 'Eye color', 'Race', 'Hair color',
#        'Height', 'Publisher', 'Skin color', 'Alignment', 'Weight'],
#       dtype='object')

# %% [markdown]
# ##### Rename my Data :

# %%
df.rename(columns={"Gender":"Real_Gender","Height":"Total_Height","Weight":"Total_Weight"},inplace=True)

# %% [markdown]
# ##### To see Data rename our Data Values or Not !

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    734 non-null    int64
#  1   name          734 non-null    object
#  2   Real_Gender   734 non-null    object
#  3   Eye color     734 non-null    object
#  4   Race          734 non-null    object
#  5   Hair color    734 non-null    object
#  6   Total_Height  734 non-null    float64
#  7   Publisher     719 non-null    object
#  8   Skin color    734 non-null    object
#  9   Alignment     734 non-null    object
#  10  Total_Weight  732 non-null    float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 63.2+ KB

# %% [markdown]
# #####  Data Describe !

# %%
df.describe()
# Out:
#        Unnamed: 0  Total_Height  Total_Weight
# count  734.000000    734.000000    732.000000
# mean   366.500000    102.254087     43.855191
# std    212.031837    139.624543    130.823733
# min      0.000000    -99.000000    -99.000000
# 25%    183.250000    -99.000000    -99.000000
# 50%    366.500000    175.000000     62.000000
# 75%    549.750000    185.000000     90.000000
# max    733.000000    975.000000    900.000000

# %%
a = df.describe(include = "all")

# %% [markdown]
# ##### (Loc) is used Poition Base Data Insert

# %%
a.loc[["top","mean"]]
# Out:
#       Unnamed: 0     name Real_Gender Eye color Race Hair color  Total_Height  \
# top          NaN  Goliath        Male      blue    -          -           NaN
# mean       366.5      NaN         NaN       NaN  NaN        NaN    102.254087
#
#           Publisher Skin color Alignment  Total_Weight
# top   Marvel Comics          -      good           NaN
# mean            NaN        NaN       NaN     43.855191

# %% [markdown]
# ##### (i.loc) is used to by indexing pick Data

# %%
a.iloc[[1,2,3]]
# Out:
#         Unnamed: 0     name Real_Gender Eye color Race Hair color  \
# unique         NaN      715           3        23   62         30
# top            NaN  Goliath        Male      blue    -          -
# freq           NaN        3         505       225  304        172
#
#         Total_Height      Publisher Skin color Alignment  Total_Weight
# unique           NaN             24         17         4           NaN
# top              NaN  Marvel Comics          -      good           NaN
# freq             NaN            388        662       496           NaN

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'Real_Gender', 'Eye color', 'Race', 'Hair color',
#        'Total_Height', 'Publisher', 'Skin color', 'Alignment', 'Total_Weight'],
#       dtype='object')

# %% [markdown]
# ##### To see all Max Rown and Columns

# %%
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
df[["Real_Gender","Eye color","Total_Weight"]]
# Out:
#     Real_Gender                Eye color  Total_Weight
# 0          Male                   yellow         441.0
# 1          Male                     blue          65.0
# 2          Male                     blue          90.0
# 3          Male                    green         441.0
# 4          Male                     blue         -99.0
# 5          Male                     blue         122.0
# 6          Male                     blue         -99.0
# 7          Male                     blue          88.0
# 8        Female                     blue          61.0
# 9          Male                    brown          81.0
# 10         Male                        -         104.0
# 11         Male                     blue         108.0
# 12         Male                    brown          90.0
# 13         Male                     blue          90.0
# 14         Male                        -         -99.0
# 15         Male                        -         -99.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'Real_Gender', 'Eye color', 'Race', 'Hair color',
#        'Total_Height', 'Publisher', 'Skin color', 'Alignment', 'Total_Weight'],
#       dtype='object')

# %% [markdown]
# ##### Mean :

# %%
df["Total_Weight"].mean()
# Out:
# 43.8551912568306

# %% [markdown]
# ##### Mode :

# %%
df["Total_Weight"].mode()
# Out:
# 0   -99.0
# Name: Total_Weight, dtype: float64

# %% [markdown]
# ##### Median :

# %%
df[["Total_Weight"]].median()
# Out:
# Total_Weight    62.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'Real_Gender', 'Eye color', 'Race', 'Hair color',
#        'Total_Height', 'Publisher', 'Skin color', 'Alignment', 'Total_Weight'],
#       dtype='object')

# %% [markdown]
# ##### Count :

# %%
df[["Total_Weight"]].value_counts()
# Out:
# Total_Weight
# -99.0           237
#  79.0            23
#  54.0            23
#  81.0            22
#  90.0            19
#  86.0            15
#  52.0            15
#  59.0            14
#  61.0            13
#  56.0            13
#  77.0            13
#  50.0            12
#  101.0           12
#  63.0            11
#  88.0            11
#  95.0            10
#  74.0            10
#  83.0            10
#  65.0             9
#  72.0             8
#  104.0            8
#  68.0             8
#  135.0            8
#  97.0             7
#  57.0             7
#  99.0             7
#  117.0            6
#  108.0            6
#  70.0             5
#  158.0            5
#  58.0             5
#  55.0             5
#  191.0            4
#  225.0            4
#  113.0            4
#  203.0            4
#  146.0            4
#  89.0             3
#  91.0             3
#  106.0            3
#  62.0             3
#  110.0            3
#  71.0             3
#  67.0             3
# ...

# %% [markdown]
# ##### Graphs :

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'Real_Gender', 'Eye color', 'Race', 'Hair color',
#        'Total_Height', 'Publisher', 'Skin color', 'Alignment', 'Total_Weight'],
#       dtype='object')

# %% [markdown]
# ##### Bar Graph :

# %%
df[["Total_Weight"]].value_counts().plot(kind="bar",title="Total_Weight",color="Red")
# Out:
# <Axes: title={'center': 'Total_Weight'}, xlabel='Total_Weight'>

# %% [markdown]
# ##### Hist Color :

# %%
df[["name"]].value_counts().plot(kind="hist",title="Total_Weight",color="black")
# Out:
# <Axes: title={'center': 'Total_Weight'}, ylabel='Frequency'>

# %% [markdown]
# ##### Null Values :

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# name             0
# Real_Gender      0
# Eye color        0
# Race             0
# Hair color       0
# Total_Height     0
# Publisher       15
# Skin color       0
# Alignment        0
# Total_Weight     2
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'Real_Gender', 'Eye color', 'Race', 'Hair color',
#        'Total_Height', 'Publisher', 'Skin color', 'Alignment', 'Total_Weight'],
#       dtype='object')

# %%
df[df["name"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, Real_Gender, Eye color, Race, Hair color, Total_Height, Publisher, Skin color, Alignment, Total_Weight]
# Index: []

# %%
df.groupby("name").describe()
# Out:
#                           Unnamed: 0                                         \
#                                count   mean       std    min     25%    50%
# name
# A-Bomb                           1.0    0.0       NaN    0.0    0.00    0.0
# Abe Sapien                       1.0    1.0       NaN    1.0    1.00    1.0
# Abin Sur                         1.0    2.0       NaN    2.0    2.00    2.0
# Abomination                      1.0    3.0       NaN    3.0    3.00    3.0
# Abraxas                          1.0    4.0       NaN    4.0    4.00    4.0
# Absorbing Man                    1.0    5.0       NaN    5.0    5.00    5.0
# Adam Monroe                      1.0    6.0       NaN    6.0    6.00    6.0
# Adam Strange                     1.0    7.0       NaN    7.0    7.00    7.0
# Agent 13                         1.0    8.0       NaN    8.0    8.00    8.0
# Agent Bob                        1.0    9.0       NaN    9.0    9.00    9.0
# ...

# %%
df.to_csv("heroes_Data02.csv")
